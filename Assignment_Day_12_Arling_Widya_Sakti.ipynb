# %% [markdown]
# # Install and Load Library

# %%
# utilities packages
import datetime

# data wrangling and transformation package
import numpy as np
import pandas as pd
import statsmodels.api as sm

# data visualization package
import matplotlib.pyplot as plt
import seaborn as sns

# time series modeling
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf, month_plot

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Load Dataset

# %%
task1 = pd.read_csv("/content/drive/MyDrive/TUGAS DBIMBING SQL/task_1_1.csv")
task2 = pd.read_csv("/content/drive/MyDrive/TUGAS DBIMBING SQL/task_1_2.csv")
task3 = pd.read_csv("/content/drive/MyDrive/TUGAS DBIMBING SQL/task_1_3.csv")
task4 = pd.read_csv("/content/drive/MyDrive/TUGAS DBIMBING SQL/task_1_4.csv")
task5 = pd.read_csv("/content/drive/MyDrive/TUGAS DBIMBING SQL/task_1_5.csv")
task6 = pd.read_csv("/content/drive/MyDrive/TUGAS DBIMBING SQL/task_1_6.csv")
task7 = pd.read_excel("/content/drive/MyDrive/TUGAS DBIMBING SQL/task_1_7.xlsx")
task8 = pd.read_excel("/content/drive/MyDrive/TUGAS DBIMBING SQL/task_1_8.xlsx")
task9 = pd.read_excel("/content/drive/MyDrive/TUGAS DBIMBING SQL/task_1_9.xlsx")
task10 = pd.read_excel("/content/drive/MyDrive/TUGAS DBIMBING SQL/task_1_10.xlsx")

# %% [markdown]
# **E-commerce Data**

# %%
# check data structure
task1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   100 non-null    int64
#  1   value   100 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 1.7 KB

# %%
# check the first 5 of rows
task1.head()
# Out:
#    index     value
# 0    101  1.323913
# 1    102  1.197747
# 2    103 -0.951691
# 3    104  1.904784
# 4    105 -0.551699

# %%
# check data structure
task2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   100 non-null    int64
#  1   value   100 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 1.7 KB

# %%
# check the first 5 of rows
task2.head()
# Out:
#    index     value
# 0    101  1.323695
# 1    102  1.198352
# 2    103 -0.948819
# 3    104  1.909786
# 4    105 -0.557036

# %%
# check data structure
task3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   100 non-null    int64
#  1   value   100 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 1.7 KB

# %%
# check the first 5 of rows
task3.head()
# Out:
#    index     value
# 0    101  1.311839
# 1    102  1.190370
# 2    103 -0.990590
# 3    104  1.901097
# 4    105 -0.522820

# %%
# check data structure
task4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   100 non-null    int64
#  1   value   100 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 1.7 KB

# %%
# check the first 5 of rows
task4.head()
# Out:
#    index     value
# 0    101  2.362450
# 1    102  3.849367
# 2    103  2.421574
# 3    104  5.052382
# 4    105  4.103413

# %%
# check data structure
task5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   100 non-null    int64
#  1   value   100 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 1.7 KB

# %%
# check the first 5 of rows
task5.head()
# Out:
#    index     value
# 0    101 -1.405059
# 1    102  0.471055
# 2    103 -0.006376
# 3    104  1.030057
# 4    105  0.207344

# %%
# check data structure
task6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   100 non-null    int64
#  1   value   100 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 1.7 KB

# %%
# check the first 5 of rows
task6.head()
# Out:
#    index     value
# 0    101  1.283148
# 1    102  1.120474
# 2    103 -1.012183
# 3    104  1.957444
# 4    105 -0.661834

# %%
# check data structure
task7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   100 non-null    datetime64[ns]
#  1   value   100 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 1.7 KB

# %%
# check the first 5 of rows
task7.head()
# Out:
#        index         value
# 0 2022-01-01  1.434675e+16
# 1 2022-02-01  1.487739e+16
# 2 2022-03-01  1.663007e+15
# 3 2022-04-01  1.874219e+16
# 4 2022-05-01  1.765772e+16

# %%
# check data structure
task8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   100 non-null    datetime64[ns]
#  1   value   100 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 1.7 KB

# %%
# check the first 5 of rows
task8.head()
# Out:
#        index              value
# 0 2022-01-01    301021996662275
# 1 2022-02-01   5008107191163410
# 2 2022-03-01  43038005872056000
# 3 2022-04-01  38070556312321400
# 4 2022-05-01  13479506260801600

# %%
# check data structure
task9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   100 non-null    datetime64[ns]
#  1   value   100 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 1.7 KB

# %%
# check the first 5 of rows
task9.head()
# Out:
#        index              value
# 0 2022-01-01   1839926835157180
# 1 2022-02-01  17123564134297000
# 2 2022-03-01  27612350517973900
# 3 2022-04-01   2977488211128050
# 4 2022-05-01  16810758670379700

# %%
# check data structure
task10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   100 non-null    datetime64[ns]
#  1   value   100 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 1.7 KB

# %%
# check the first 5 of rows
task10.head()
# Out:
#        index         value
# 0 2022-01-01  1.672403e+16
# 1 2022-02-01  4.048346e+15
# 2 2022-03-01  8.983162e+14
# 3 2022-04-01 -5.074511e+15
# 4 2022-05-01 -3.305332e+15

# %% [markdown]
# Simple Line Chart

# %%
# simple line chart

task1.plot(
    x = 'index', 
    y = 'value',
    figsize = (14,5)
)
plt.title("Index_value")
plt.ylabel("value")
plt.show()

# %%
# simple line chart

task2.plot(
    x = 'index', 
    y = 'value',
    figsize = (14,5)
)
plt.title("Index_value")
plt.ylabel("value")
plt.show()

# %%
# simple line chart

task3.plot(
    x = 'index', 
    y = 'value',
    figsize = (14,5)
)
plt.title("Index_value")
plt.ylabel("value")
plt.show()

# %%
# simple line chart

task4.plot(
    x = 'index', 
    y = 'value',
    figsize = (14,5)
)
plt.title("Index_value")
plt.ylabel("value")
plt.show()

# %%
# simple line chart

task5.plot(
    x = 'index', 
    y = 'value',
    figsize = (14,5)
)
plt.title("Index_value")
plt.ylabel("value")
plt.show()

# %%
# simple line chart

task6.plot(
    x = 'index', 
    y = 'value',
    figsize = (14,5)
)
plt.title("Index_value")
plt.ylabel("value")
plt.show()

# %%
# simple line chart

task7.plot(
    x = 'index', 
    y = 'value',
    figsize = (14,5)
)
plt.title("Index_value")
plt.ylabel("value")
plt.show()

# %%
# simple line chart

task8.plot(
    x = 'index', 
    y = 'value',
    figsize = (14,5)
)
plt.title("Index_value")
plt.ylabel("value")
plt.show()

# %%
# simple line chart

task9.plot(
    x = 'index', 
    y = 'value',
    figsize = (14,5)
)
plt.title("Index_value")
plt.ylabel("value")
plt.show()

# %%
# simple line chart

task10.plot(
    x = 'index', 
    y = 'value',
    figsize = (14,5)
)
plt.title("Index_value")
plt.ylabel("value")
plt.show()

# %% [markdown]
# Exploratory Method for Time Series

# %% [markdown]
# Seasonal Plot

# %%
# create month and year column
task7['Week'] = task7['index'].dt.weekday
task7['Month'] = task7['index'].dt.month
task7['Year'] = task7['index'].dt.year

# %%
# create seasonal plot - monthly
plt.figure(figsize=(14,5))
sns.lineplot(
    data = task7,
    x = 'Month',
    y = 'value',
    hue = 'Year',
    legend = 'full'
)
plt.title("Total value ")
plt.show()

# %%
# create seasonal plot - week
plt.figure(figsize=(14,5))
sns.lineplot(
    data = task7,
    x = 'Week',
    y = 'value',
    hue = 'Year',
    legend = 'full'
)
plt.title("Total value")
plt.show()

# %%
# create month and year column
task8['Week'] = task8['index'].dt.weekday
task8['Month'] = task8['index'].dt.month
task8['Year'] = task8['index'].dt.year

# %%
# create seasonal plot - monthly
plt.figure(figsize=(14,5))
sns.lineplot(
    data = task8,
    x = 'Month',
    y = 'value',
    hue = 'Year',
    legend = 'full'
)
plt.title("Total value")
plt.show()

# %%
# create seasonal plot - week
plt.figure(figsize=(14,5))
sns.lineplot(
    data = task8,
    x = 'Week',
    y = 'value',
    hue = 'Year',
    legend = 'full'
)
plt.title("Total value")
plt.show()

# %%
# create month and year column
task9['Week'] = task9['index'].dt.weekday
task9['Month'] = task9['index'].dt.month
task9['Year'] = task9['index'].dt.year

# %%
# create seasonal plot - monthly
plt.figure(figsize=(14,5))
sns.lineplot(
    data = task9,
    x = 'Month',
    y = 'value',
    hue = 'Year',
    legend = 'full'
)
plt.title("Total value")
plt.show()

# %%
# create seasonal plot - week
plt.figure(figsize=(14,5))
sns.lineplot(
    data = task9,
    x = 'Week',
    y = 'value',
    hue = 'Year',
    legend = 'full'
)
plt.title("Total value")
plt.show()

# %%
# create month and year column
task10['Week'] = task10['index'].dt.weekday
task10['Month'] = task10['index'].dt.month
task10['Year'] = task10['index'].dt.year

# %%
# create seasonal plot - monthly
plt.figure(figsize=(14,5))
sns.lineplot(
    data = task10,
    x = 'Month',
    y = 'value',
    hue = 'Year',
    legend = 'full'
)
plt.title("Total value")
plt.show()

# %%
# create seasonal plot - week
plt.figure(figsize=(14,5))
sns.lineplot(
    data = task10,
    x = 'Week',
    y = 'value',
    hue = 'Year',
    legend = 'full'
)
plt.title("Total value")
plt.show()

# %% [markdown]
# Lag Plot

# %%
# create lag plot from 1 to 9
# Plot
fig, axes = plt.subplots(nrows = 3, ncols=3, figsize=(10,10), sharex=True, sharey=True, dpi=100)
for i, ax in enumerate(axes.flatten()[:9]):
    pd.plotting.lag_plot(task4['value'], lag=i+1, ax=ax, c='firebrick')
    ax.set_title('Lag ' + str(i+1))
plt.show()

# %%
# create lag plot from 1 to 9
# Plot
fig, axes = plt.subplots(nrows = 3, ncols=3, figsize=(10,10), sharex=True, sharey=True, dpi=100)
for i, ax in enumerate(axes.flatten()[:9]):
    pd.plotting.lag_plot(task9['value'], lag=i+1, ax=ax, c='firebrick')
    ax.set_title('Lag ' + str(i+1))
plt.show()

# %% [markdown]
# ACF & PACF

# %%
# ACF plot
plot_acf(
    task1['value'], 
    lags = 36
).set_size_inches((14,5));

# %%
# PACF plot
plot_pacf(
    task1['value'], 
    lags = 36
).set_size_inches((14,5));

# %%
# ACF plot
plot_acf(
    task2['value'], 
    lags = 36
).set_size_inches((14,5));

# %%
# PACF plot
plot_pacf(
    task2['value'], 
    lags = 36
).set_size_inches((14,5));

# %%
# ACF plot
plot_acf(
    task3['value'], 
    lags = 36
).set_size_inches((14,5));

# %%
# PACF plot
plot_pacf(
    task3['value'], 
    lags = 36
).set_size_inches((14,5));

# %%
# ACF plot
plot_acf(
    task4['value'], 
    lags = 36
).set_size_inches((14,5));

# %%
# PACF plot
plot_pacf(
    task4['value'], 
    lags = 36
).set_size_inches((14,5));

# %%
# ACF plot
plot_acf(
    task5['value'], 
    lags = 36
).set_size_inches((14,5));

# %%
# PACF plot
plot_pacf(
    task5['value'], 
    lags = 36
).set_size_inches((14,5));

# %%
# ACF plot
plot_acf(
    task6['value'], 
    lags = 36
).set_size_inches((14,5));

# %%
# PACF plot
plot_pacf(
    task6['value'], 
    lags = 36
).set_size_inches((14,5));

# %%
# ACF plot
plot_acf(
    task7['value'], 
    lags = 36
).set_size_inches((14,5));

# %%
# PACF plot
plot_pacf(
    task7['value'], 
    lags = 36
).set_size_inches((14,5));

# %%
# ACF plot
plot_acf(
    task8['value'], 
    lags = 36
).set_size_inches((14,5));

# %%
# PACF plot
plot_pacf(
    task8['value'], 
    lags = 36
).set_size_inches((14,5));

# %%
# ACF plot
plot_acf(
    task9['value'], 
    lags = 36
).set_size_inches((14,5));

# %%
# PACF plot
plot_pacf(
    task9['value'], 
    lags = 36
).set_size_inches((14,5));

# %%
# ACF plot
plot_acf(
    task10['value'], 
    lags = 36
).set_size_inches((14,5));

# %%
# PACF plot
plot_pacf(
    task10['value'], 
    lags = 36
).set_size_inches((14,5));

# %% [markdown]
# Nomor 1 :
# Interpretasi dari data time series diatas seelumnya peneliti menarik data dari drive kemudian melihat data tersebut ada 10 data, kemudian dilakukan pengecekan dan simple line data, sebelumnya peneliti merubah date data dari type 7-10 karena tidak terbaca d google colab.
# Dari hasil diatas peneliti ingin melihat lag apakah ada korelasi antara bulan februari ke bulan lainnya karena datanny tahunan, untuk lag data task 4 secara sekilas bisa dilihta bahwa data lag 1 memiliki korelasi dengan bulan sebelumnya dan dari polanya juga semakin lama semakin melebar.
# - task1 jenis Data tidak memiliki confidense internal bentuk pola terlihat datar tidak ada yang signifikan lagnya jadi masuk data random walk/white noise
# - task2 jenis Data  tidak memiliki confidense internal bentuk pola terlihat datar tidak ada yang signifikan lagnya jadi masuk data random walk/white noise
# - task3 jenis Data tidak memiliki confidense internal bentuk pola terlihat datar tidak ada yang signifikan lagnya jadi masuk data random walk/white noise.
#
# - task4 jenis Data memiliki confidence interval yang bentuknya kerucut dan bergelombang jadi masuk kategori AR karena menurun secara eksponensial atau berpola gelombang sinus
# - task5 jenis Data tidak memiliki confidense internal bentuk pola terlihat datar tidak ada yang signifikan lagnya jadi masuk data random walk/white noise
# - task6 jenis Data tidak memiliki confidense internal bentuk pola terlihat datar tidak ada yang signifikan lagnya jadi masuk data random walk/white noise
# - task7 jenis Data jika dilihat pacfnya ada yang signifikan di lag dua maka masuk kategori AR 2 (autoregressive 2)
# - task8 jenis Data jika dilihat pacfnya ada yang signifikan di lag pertama maka masuk kategori AR  (autoregressive )
# - task9 jenis Data tidak memiliki confidense internal bentuk pola terlihat datar ada ada yang signifikan dilag 16 maka masuk kategori AR (autoregressive )
# - task10 jenis Data tidak memiliki confidense internal bentuk pola terlihat datar tidak ada yang signifikan lagnya jadi masuk data random walk/white noise

# %% [markdown]
# Soal 2
# Hitunglah jumlah pembeli, jumlah transaksi, GMV, dan profit yang diperoleh dengan rentang waktu berikut:
# Harian
# Mingguan
# Bulanan

# %%
# utilities packages
import datetime


# data wrangling and transformation package
import numpy as np
import pandas as pd
import statsmodels.api as sm

# data visualization package
import matplotlib.pyplot as plt
import seaborn as sns

# time series modeling
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf, month_plot

# %matplotlib inline
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# !pip install sktime
# Out:
# ...
#      |████████████████████████████████| 6.7 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 9.8 MB 50.2 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 52.5 MB/s
# ...
#      |████████████████████████████████| 34.5 MB 15 kB/s
# ...
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.34.0
#     Uninstalling llvmlite-0.34.0:
#       Successfully uninstalled llvmlite-0.34.0
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
#   Attempting uninstall: numba
#     Found existing installation: numba 0.51.2
#     Uninstalling numba-0.51.2:
#       Successfully uninstalled numba-0.51.2
# ...

# %%
# load dataset
dataset = pd.read_csv("https://raw.githubusercontent.com/hadimaster65555/dataset_for_teaching/main/dataset/time_series_data/superstore_time_series_dataset/superstore_train.csv", encoding="latin-1")

# %%
# check data structure
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         8000 non-null   int64
#  1   Order ID       8000 non-null   object
#  2   Order Date     8000 non-null   object
#  3   Ship Date      8000 non-null   object
#  4   Ship Mode      8000 non-null   object
#  5   Customer ID    8000 non-null   object
#  6   Customer Name  8000 non-null   object
#  7   Segment        8000 non-null   object
#  8   Country        8000 non-null   object
#  9   City           8000 non-null   object
#  10  State          8000 non-null   object
#  11  Postal Code    8000 non-null   int64
#  12  Region         8000 non-null   object
#  13  Product ID     8000 non-null   object
#  14  Category       8000 non-null   object
#  15  Sub-Category   8000 non-null   object
#  16  Product Name   8000 non-null   object
# ...

# %%
dataset.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-06-12  2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812  2014-06-09  2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812  2014-06-09  2014-06-14  Standard Class    BH-11710
# 7       8  CA-2014-115812  2014-06-09  2014-06-14  Standard Class    BH-11710
# 8       9  CA-2014-115812  2014-06-09  2014-06-14  Standard Class    BH-11710
# 9      10  CA-2014-115812  2014-06-09  2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...
