# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Superstore.xlsx')

# %%
df.head()
# Out:
#    Row ID        Order ID           Order Date            Ship Date  \
# 0       1  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 1       2  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 2       3  CA-2016-138688  2016-12-06 00:00:00            6/16/2016
# 3       4  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# 4       5  US-2015-108966  2015-11-10 00:00:00           10/18/2015
#
#         Ship Mode Customer ID    Customer Name    Segment        Country  \
# 0    Second Class    CG-12520      Claire Gute   Consumer  United States
# 1    Second Class    CG-12520      Claire Gute   Consumer  United States
# 2    Second Class    DV-13045  Darrin Van Huff  Corporate  United States
# 3  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States
# 4  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States
#
#               City  ... Postal Code  Region       Product ID         Category  \
# 0        Henderson  ...       42420   South  FUR-BO-10001798        Furniture
# 1        Henderson  ...       42420   South  FUR-CH-10000454        Furniture
# 2      Los Angeles  ...       90036    West  OFF-LA-10000240  Office Supplies
# 3  Fort Lauderdale  ...       33311   South  FUR-TA-10000577        Furniture
# 4  Fort Lauderdale  ...       33311   South  OFF-ST-10000760  Office Supplies
#
#   Sub-Category                                       Product Name       Sales  \
# 0    Bookcases                  Bush Somerset Collection Bookcase      261.96
# 1       Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...      731.94
# 2       Labels  Self-Adhesive Address Labels for Typewriters b...       14.62
# 3       Tables      Bretford CR4500 Series Slim Rectangular Table  9575775.00
# 4      Storage                     Eldon Fold 'N Roll Cart System    22368.00
#
#    Quantity  Discount    Profit
# 0       2.0      0.00  419136.0
# 1       3.0      0.00  219582.0
# 2       2.0      0.00   68714.0
# 3       5.0      0.45 -383031.0
# 4       2.0      0.20   25164.0
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000  9.988000e+03  9988.000000  9988.000000
# mean   4997.500000  55190.379428  1.008687e+05     3.788646     0.156196
# std    2885.163629  32063.693350  5.184267e+05     2.224976     0.206506
# min       1.000000   1040.000000  4.440000e-01     1.000000     0.000000
# 25%    2499.250000  23223.000000  3.975000e+01     2.000000     0.000000
# 50%    4997.500000  56430.500000  3.487000e+02     3.000000     0.200000
# 75%    7495.750000  90008.000000  2.517600e+04     5.000000     0.200000
# max    9994.000000  99301.000000  2.396266e+07    14.000000     0.800000
#
#              Profit
# count  9.988000e+03
# mean   1.796184e+05
# std    1.723468e+06
# min   -3.839990e+07
# 25%    1.878750e+01
# 50%    3.628800e+04
# 75%    1.508940e+05
# max    6.719981e+07

# %%
df.isna()
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
# ...      ...       ...         ...        ...        ...          ...
# 9989   False     False       False      False      False        False
# 9990   False     False       False      False      False        False
# 9991   False     False       False      False      False        False
# 9992   False     False       False      False      False        False
# 9993   False     False       False      False      False        False
#
#       Customer Name  Segment  Country   City  ...  Postal Code  Region  \
# 0             False    False    False  False  ...        False   False
# 1             False    False    False  False  ...        False   False
# 2             False    False    False  False  ...        False   False
# 3             False    False    False  False  ...        False   False
# 4             False    False    False  False  ...        False   False
# ...             ...      ...      ...    ...  ...          ...     ...
# 9989          False    False    False  False  ...        False   False
# 9990          False    False    False  False  ...        False   False
# 9991          False    False    False  False  ...        False   False
# 9992          False    False    False  False  ...        False   False
# 9993          False    False    False  False  ...        False   False
#
#       Product ID  Category  Sub-Category  Product Name  Sales  Quantity  \
# 0          False     False         False         False  False     False
# 1          False     False         False         False  False     False
# 2          False     False         False         False  False     False
# 3          False     False         False         False  False     False
# 4          False     False         False         False  False     False
# ...          ...       ...           ...           ...    ...       ...
# 9989       False     False         False         False  False     False
# 9990       False     False         False         False  False     False
# 9991       False     False         False         False  False     False
# 9992       False     False         False         False  False     False
# 9993       False     False         False         False  False     False
#
#       Discount  Profit
# 0        False   False
# 1        False   False
# 2        False   False
# 3        False   False
# 4        False   False
# ...        ...     ...
# 9989     False   False
# 9990     False   False
# 9991     False   False
# 9992     False   False
# 9993     False   False
#
# [9994 rows x 21 columns]

# %%
df['Profit'].mean()
# Out:
# 179618.44033312003

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
df['Category'] = lb.fit_transform(df['Category'])
df
# Out:
#       Row ID        Order ID           Order Date            Ship Date  \
# 0          1  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 1          2  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 2          3  CA-2016-138688  2016-12-06 00:00:00            6/16/2016
# 3          4  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# 4          5  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# ...      ...             ...                  ...                  ...
# 9989    9990  CA-2014-110422            1/21/2014            1/23/2014
# 9990    9991  CA-2017-121258            2/26/2017  2017-03-03 00:00:00
# 9991    9992  CA-2017-121258            2/26/2017  2017-03-03 00:00:00
# 9992    9993  CA-2017-121258            2/26/2017  2017-03-03 00:00:00
# 9993    9994  CA-2017-119914  2017-04-05 00:00:00  2017-09-05 00:00:00
#
#            Ship Mode Customer ID     Customer Name    Segment        Country  \
# 0       Second Class    CG-12520       Claire Gute   Consumer  United States
# 1       Second Class    CG-12520       Claire Gute   Consumer  United States
# 2       Second Class    DV-13045   Darrin Van Huff  Corporate  United States
# 3     Standard Class    SO-20335    Sean O'Donnell   Consumer  United States
# 4     Standard Class    SO-20335    Sean O'Donnell   Consumer  United States
# ...              ...         ...               ...        ...            ...
# 9989    Second Class    TB-21400  Tom Boeckenhauer   Consumer  United States
# 9990  Standard Class    DB-13060       Dave Brooks   Consumer  United States
# 9991  Standard Class    DB-13060       Dave Brooks   Consumer  United States
# 9992  Standard Class    DB-13060       Dave Brooks   Consumer  United States
# 9993    Second Class    CC-12220      Chris Cortes   Consumer  United States
#
#                  City  ... Postal Code  Region       Product ID Category  \
# 0           Henderson  ...       42420   South  FUR-BO-10001798        0
# 1           Henderson  ...       42420   South  FUR-CH-10000454        0
# 2         Los Angeles  ...       90036    West  OFF-LA-10000240        1
# 3     Fort Lauderdale  ...       33311   South  FUR-TA-10000577        0
# 4     Fort Lauderdale  ...       33311   South  OFF-ST-10000760        1
# ...               ...  ...         ...     ...              ...      ...
# 9989            Miami  ...       33180   South  FUR-FU-10001889        0
# 9990       Costa Mesa  ...       92627    West  FUR-FU-10000747        0
# 9991       Costa Mesa  ...       92627    West  TEC-PH-10003645        2
# 9992       Costa Mesa  ...       92627    West  OFF-PA-10004041        1
# 9993      Westminster  ...       92683    West  OFF-AP-10002684        1
#
#       Sub-Category                                       Product Name  \
# 0        Bookcases                  Bush Somerset Collection Bookcase
# 1           Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2           Labels  Self-Adhesive Address Labels for Typewriters b...
# 3           Tables      Bretford CR4500 Series Slim Rectangular Table
# 4          Storage                     Eldon Fold 'N Roll Cart System
# ...            ...                                                ...
# 9989   Furnishings                             Ultra Door Pull Handle
# 9990   Furnishings  Tenex B1-RE Series Chair Mats for Low Pile Car...
# 9991        Phones                              Aastra 57i VoIP phone
# 9992         Paper  It's Hot Message Books with Stickers, 2 3/4" x 5"
# 9993    Appliances  Acco 7-Outlet Masterpiece Power Center, Wihtou...
#
#            Sales  Quantity  Discount     Profit
# 0         261.96       2.0      0.00  419136.00
# 1         731.94       3.0      0.00  219582.00
# 2          14.62       2.0      0.00   68714.00
# 3     9575775.00       5.0      0.45 -383031.00
# 4       22368.00       2.0      0.20   25164.00
# ...          ...       ...       ...        ...
# 9989    25248.00       3.0      0.20   41028.00
# 9990       91.96       2.0      0.00  156332.00
# 9991   258576.00       2.0      0.20  193932.00
# 9992       29.60       4.0      0.00      13.32
# 9993      243.16       2.0      0.00   72948.00
#
# [9994 rows x 21 columns]

# %%
x =df.iloc[:,1:22].values # = x
y =df.iloc[:,0].values # = y

# %%
sns.pairplot(df, vars= ['Sales', 'Quantity', 'Discount', 'Profit'], hue ='Category') 

plt.ioff
# Out:
# <function matplotlib.pyplot.ioff>

# %%
sns.countplot(df['Category'])
plt.ioff()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.corr()
# Out:
#                Row ID  Postal Code  Category     Sales  Quantity  Discount  \
# Row ID       1.000000     0.009671 -0.004565 -0.013333 -0.003402  0.013560
# Postal Code  0.009671     1.000000 -0.002331  0.032129  0.012782  0.058551
# Category    -0.004565    -0.002331  1.000000 -0.065565 -0.004304 -0.063000
# Sales       -0.013333     0.032129 -0.065565  1.000000  0.093681  0.105951
# Quantity    -0.003402     0.012782 -0.004304  0.093681  1.000000  0.008547
# Discount     0.013560     0.058551 -0.063000  0.105951  0.008547  1.000000
# Profit       0.004504    -0.022367  0.087961  0.010396  0.062099 -0.180740
#
#                Profit
# Row ID       0.004504
# Postal Code -0.022367
# Category     0.087961
# Sales        0.010396
# Quantity     0.062099
# Discount    -0.180740
# Profit       1.000000

# %%
sns.heatmap(df.corr())

# %%
plt.figure(figsize=(16,6))
heatmap = sns.heatmap(df.corr(), vmin =-1, vmax=1, annot=True)
heatmap.set_title('Correlation HeatMap', fontdict={'fontsize':12}, pad=12);

# %%
a = 'rumah saya di jakarta' 
a[12]
# Out:
# 'i'
